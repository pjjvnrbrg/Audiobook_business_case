# %% [markdown]
# # Scenario
# A dataset of an audio book app contains information (metrics) of customers/users that have made atleast one in-app purchase. The goal is to create a model that will predict if the customer will buy again based on certain metrics. The reason for the model is so that we can properly identify how the company should spend advertising resources in order to keep fans buying and not wasting resources on alienated customers since they are unlikely to buy anyway. In this way improved sales and profitability can be obtained.
#
# The model is ultimatly a human behaviour predictor and as a side effect the most important metrics as predictors will be identified.

# %% [markdown]
# # Resources
# A .csv file is supplied. Each row is a customer with a unique ID.
#
# The first two metrics included are Overall Booklength (sum of all purchased books length) and Average Booklength (Overall/number of books), naturally the number of books purchased can be derived from these two variables.
#
# Following on, Overall Price (sum) and Average Price follow the same logic in USD. Intuitivly, price is almost always a good predictor, we expect one of these to be an important metric.
#
# Next we have Review (boolean), it shows if the customer has engaged with the company atleast once. It is likely that an engaging customer should return. Next, Review 10/10 is a quantified, average measure of Review - attitude towards content/platform/medium.
#
# Total minutes listened is the cumulative sum of playback time when listening to a book. This serves as a measure of how much time the customer spends on the app. A measure of engament. If you spend more time on the app you will be exposed to more content and therefore buy again.
#
# Completion shows the percentage of content completed (total length of books/total minutes listened). A shortfall is that people do not relisten to books. You could test for this or include a metric to track replays.
#
# Support requests is the total number of requests the person has opened. A measure of engagement of an inverse nature. More requests could mean they have a bad experience and leave the platform all together. Or it could be feeding back positive interactions and stimulates.
#
# Last visited - Purchase date. A measure of engagement (recency). The larger the value the more recent.
#
# ## How was the data gathered?
# Data was gathered from the app and is 2 years worth of engagement. An extra 6 months of data was used to check for customer conversion.
#
# ## Targets?
# We will use supervised learning, the target will be a boolean. 1 if conversion occured and 0 if not. Conversion is defined by if another book was purchased after the initial 2 years of data in the follow up 6 months.

# %% [markdown]
# # Method
# ## Input data
# The inputs should be scaled or sandardized. The dataset should also be shuffled,balanced and batched.
#
# ## Forward propagation in hidden layers
# Each input will be weighted and biased linearly (dot product) to each neuron in the following layer(s) and finally transformed non-linearly using a specific activation function before being forward propagated into the next layer. This is then repeated for n hidden layers.
#
# ## Output data
# A 1-hot encoded output lends itself nicely to a classification system rather than a vector of probabilities. The final activation function will be a Softmax function since the output vector should be 1x2 in size and be 1-hot encoded. The final activation function will be a Softmax function.
#
# ## Back propagation
# The Adaptive Moment Estimation (ADAM) optimiser will be used. The loss will be determined using sparse categorical cross entropy since the targets should be 1-hot encoded.
#
# ## Steps
# ### Import packages
# ### Helper functions
# ### Load the data
# ### Preprocessing
# #### Missing Values
# #### Standardise or scale the data
# #### Shuffle the data
# #### Balance the data
# #### Shuffle the data again
# #### Split into training, validation and test sets
# ### Outline the model(s)
# ### Train the model(s)
# ### Test the model

# %% [markdown]
# ### Import packages

# %%
# import data and table packages
import pandas as pd
import numpy as np

# import graphing tools


# import ML packages
from sklearn import preprocessing
import tensorflow as tf

# %% [markdown]
# ### Helper functions

# %%
# Create the model contructs
def construct(output_length, optimizer='adam', mode='sequential', flatten_input=True, list_of_widths=[50], list_of_depths=[2]):
    dict = {}
    #if mode is sequential then
    if mode.lower() == 'sequential': 
        # for the number of widths
        for w in list_of_widths:
            # for the number of depths 
            for d in list_of_depths:
                # create a label for the dictionary
                label = str(w) + 'x' + str(d)
                print(f"Constructing a {label} model")
                # instantiate the model object
                if flatten_input is True:
                    model = tf.keras.Sequential([
                        # input layer:
                        #           flatten the tensor into a vector using an inbuilt method of tensor flow
                        tf.keras.layers.Flatten(input_shape=(28,28,1))])
                else:
                    model = tf.keras.Sequential()
                # for d layers
                for x in range(d):
                    # add a hidden layer of width w
                    model.add(tf.keras.layers.Dense(w,activation = 'relu'))
                # add the output layer
                model.add(tf.keras.layers.Dense(output_length,activation = 'softmax'))
                # choose the optimizer and loss functions
                model.compile(optimizer=optimizer,loss='sparse_categorical_crossentropy',metrics=['accuracy'])
                # save in the dicitonary
                dict[label] = model
    return dict

def shuffle(data):
    # Save the column names
    cols = data.columns.to_list()
    # create evenly spaced values in the inputs dataframe
    shuffled_indices = np.arange(data.values.shape[0])
    # shuffle randomly
    np.random.shuffle(shuffled_indices)
    # set the new indices positions from the shuffle data on the non-shuffled data. Save as a Dataframe for intuitive veiwing using the cols saved
    data = pd.DataFrame(data.values[shuffled_indices],columns=cols)
    return data

# a helper function to cast a value into tf.int64
def cast_to_tf_integer(x):
    # if x is not a tf.int64 object then
    if type(x) is not tf.int64:
        # cast x as a tf.int64
        x = tf.cast(x, tf.int64) 
    return x

# a helper function to cast a value into tf.float32
def cast_to_tf_float(x):
    # if x is not a tf.float32 object then
    if type(x) is not tf.float32:
        #cast x as a tf.float32
        x = tf.cast(x, tf.float32)
    return x

# %% [markdown]
# ### Load the data

# %%
# load csv file into a dataframe
raw_data = pd.read_csv('Audiobooks_data.csv')
raw_data
# Out:
#           ID  Book length (mins)_avg  Book length (mins)_overall  Price_avg  \
# 0        994                  1620.0                        1620      19.73
# 1       1143                  2160.0                        2160       5.33
# 2       2059                  2160.0                        2160       5.33
# 3       2882                  1620.0                        1620       5.96
# 4       3342                  2160.0                        2160       5.33
# ...      ...                     ...                         ...        ...
# 14079  28220                  1620.0                        1620       5.33
# 14080  28671                  1080.0                        1080       6.55
# 14081  31134                  2160.0                        2160       6.14
# 14082  32832                  1620.0                        1620       5.33
# 14083    251                  1674.0                        3348       5.33
#
#        Price_overall  Review  Review 10/10  Completion  Minutes_listened  \
# 0              19.73       1          10.0        0.99            1603.8
# 1               5.33       0           NaN        0.00               0.0
# 2               5.33       0           NaN        0.00               0.0
# 3               5.96       0           NaN        0.42             680.4
# 4               5.33       0           NaN        0.22             475.2
# ...              ...     ...           ...         ...               ...
# 14079           5.33       1           9.0        0.61             988.2
# 14080           6.55       1           6.0        0.29             313.2
# 14081           6.14       0           NaN        0.00               0.0
# 14082           5.33       1           8.0        0.38             615.6
# 14083          10.67       0           NaN        0.00               0.0
#
#        Support Requests  Last visited minus Purchase date  Targets
# 0                     5                                92        0
# 1                     0                                 0        0
# 2                     0                               388        0
# 3                     1                               129        0
# 4                     0                               361        0
# ...                 ...                               ...      ...
# 14079                 0                                 4        0
# 14080                 0                                29        0
# 14081                 0                                 0        0
# 14082                 0                                90        0
# 14083                 0                                 0        1
#
# [14084 rows x 12 columns]

# %%
raw_data.describe()
# Out:
#                  ID  Book length (mins)_avg  Book length (mins)_overall  \
# count  14084.000000            14084.000000                14084.000000
# mean   16772.491551             1591.281685                 1678.608634
# std     9691.807248              504.340663                  654.838599
# min        2.000000              216.000000                  216.000000
# 25%     8368.000000             1188.000000                 1188.000000
# 50%    16711.500000             1620.000000                 1620.000000
# 75%    25187.250000             2160.000000                 2160.000000
# max    33683.000000             2160.000000                 7020.000000
#
#           Price_avg  Price_overall        Review  Review 10/10    Completion  \
# count  14084.000000   14084.000000  14084.000000   2468.000000  14084.000000
# mean       7.103791       7.543805      0.160750      8.908829      0.125659
# std        4.931673       5.560129      0.367313      1.537262      0.241206
# min        3.860000       3.860000      0.000000      1.000000      0.000000
# 25%        5.330000       5.330000      0.000000      8.000000      0.000000
# 50%        5.950000       6.070000      0.000000     10.000000      0.000000
# 75%        8.000000       8.000000      0.000000     10.000000      0.130000
# max      130.940000     130.940000      1.000000     10.000000      1.000000
#
#        Minutes_listened  Support Requests  Last visited minus Purchase date  \
# count      14084.000000      14084.000000                      14084.000000
# mean         189.888983          0.070222                         61.935033
# std          371.084010          0.472157                         88.207634
# min            0.000000          0.000000                          0.000000
# 25%            0.000000          0.000000                          0.000000
# 50%            0.000000          0.000000                         11.000000
# 75%          194.400000          0.000000                        105.000000
# max         2160.000000         30.000000                        464.000000
#
#             Targets
# count  14084.000000
# mean       0.158833
# std        0.365533
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ### Preprocessing
# #### Missing Values
# Missing values appear to be in the dataset, specifically in the "Review 10/10" feature. The values need to be filled with a "status quo" or the feature is to be removed all together. Let us opt for setting a "status quo" of the midway point "5".

# %%
# fill NaN values with 5
raw_data['Review 10/10'] = raw_data['Review 10/10'].fillna(5)
raw_data
# Out:
#           ID  Book length (mins)_avg  Book length (mins)_overall  Price_avg  \
# 0        994                  1620.0                        1620      19.73
# 1       1143                  2160.0                        2160       5.33
# 2       2059                  2160.0                        2160       5.33
# 3       2882                  1620.0                        1620       5.96
# 4       3342                  2160.0                        2160       5.33
# ...      ...                     ...                         ...        ...
# 14079  28220                  1620.0                        1620       5.33
# 14080  28671                  1080.0                        1080       6.55
# 14081  31134                  2160.0                        2160       6.14
# 14082  32832                  1620.0                        1620       5.33
# 14083    251                  1674.0                        3348       5.33
#
#        Price_overall  Review  Review 10/10  Completion  Minutes_listened  \
# 0              19.73       1          10.0        0.99            1603.8
# 1               5.33       0           5.0        0.00               0.0
# 2               5.33       0           5.0        0.00               0.0
# 3               5.96       0           5.0        0.42             680.4
# 4               5.33       0           5.0        0.22             475.2
# ...              ...     ...           ...         ...               ...
# 14079           5.33       1           9.0        0.61             988.2
# 14080           6.55       1           6.0        0.29             313.2
# 14081           6.14       0           5.0        0.00               0.0
# 14082           5.33       1           8.0        0.38             615.6
# 14083          10.67       0           5.0        0.00               0.0
#
#        Support Requests  Last visited minus Purchase date  Targets
# 0                     5                                92        0
# 1                     0                                 0        0
# 2                     0                               388        0
# 3                     1                               129        0
# 4                     0                               361        0
# ...                 ...                               ...      ...
# 14079                 0                                 4        0
# 14080                 0                                29        0
# 14081                 0                                 0        0
# 14082                 0                                90        0
# 14083                 0                                 0        1
#
# [14084 rows x 12 columns]

# %% [markdown]
# #### Standardise or scale the data
# Let us use sklearn to standardise the features

# %%
# standardise the features using sklearn
standardized_data = pd.DataFrame(preprocessing.scale(raw_data.iloc[:,1:-1]),columns=raw_data.columns[1:-1])
standardized_data['Targets'] = raw_data['Targets']
standardized_data['ID'] = raw_data['ID']
standardized_data
# Out:
#        Book length (mins)_avg  Book length (mins)_overall  Price_avg  \
# 0                    0.056944                   -0.089504   2.560319
# 1                    1.127687                    0.735156  -0.359686
# 2                    1.127687                    0.735156  -0.359686
# 3                    0.056944                   -0.089504  -0.231936
# 4                    1.127687                    0.735156  -0.359686
# ...                       ...                         ...        ...
# 14079                0.056944                   -0.089504  -0.359686
# 14080               -1.013799                   -0.914164  -0.112297
# 14081                1.127687                    0.735156  -0.195436
# 14082                0.056944                   -0.089504  -0.359686
# 14083                0.164019                    2.549408  -0.359686
#
#        Price_overall    Review  Review 10/10  Completion  Minutes_listened  \
# 0           2.191789  2.284918      2.664739    3.583548          3.810353
# 1          -0.398171 -0.437653     -0.422996   -0.520980         -0.511732
# 2          -0.398171 -0.437653     -0.422996   -0.520980         -0.511732
# 3          -0.284861 -0.437653     -0.422996    1.220335          1.321880
# 4          -0.398171 -0.437653     -0.422996    0.391137          0.768886
# ...              ...       ...           ...         ...               ...
# 14079      -0.398171  2.284918      2.047192    2.008072          2.151371
# 14080      -0.178744  2.284918      0.194551    0.681356          0.332311
# 14081      -0.252486 -0.437653     -0.422996   -0.520980         -0.511732
# 14082      -0.398171  2.284918      1.429645    1.054495          1.147250
# 14083       0.562272 -0.437653     -0.422996   -0.520980         -0.511732
#
#        Support Requests  Last visited minus Purchase date  Targets     ID
# 0             10.441350                          0.340855        0    994
# 1             -0.148730                         -0.702175        0   1143
# 2             -0.148730                          3.696693        0   2059
# 3              1.969286                          0.760335        0   2882
# 4             -0.148730                          3.390586        0   3342
# ...                 ...                               ...      ...    ...
# 14079         -0.148730                         -0.656826        0  28220
# 14080         -0.148730                         -0.373394        0  28671
# 14081         -0.148730                         -0.702175        0  31134
# 14082         -0.148730                          0.318181        0  32832
# 14083         -0.148730                         -0.702175        1    251
#
# [14084 rows x 12 columns]

# %% [markdown]
# #### Shuffle the data

# %%
shuffled_data = shuffle(standardized_data)
shuffled_data
# Out:
#        Book length (mins)_avg  Book length (mins)_overall  Price_avg  \
# 0                   -0.799650                   -0.749232  -0.359686
# 1                    1.127687                    0.735156   0.181732
# 2                    1.127687                    0.735156  -0.359686
# 3                   -0.799650                   -0.749232  -0.035241
# 4                   -0.799650                   -0.749232  -0.359686
# ...                       ...                         ...        ...
# 14079               -1.013799                   -0.914164  -0.359686
# 14080               -0.799650                   -0.749232  -0.079852
# 14081               -2.726987                   -2.233620  -0.244102
# 14082                1.127687                    0.735156   0.613649
# 14083                0.056944                   -0.089504  -0.359686
#
#        Price_overall    Review  Review 10/10  Completion  Minutes_listened  \
# 0          -0.398171 -0.437653     -0.422996   -0.230761         -0.287624
# 1           0.082050 -0.437653     -0.422996   -0.272221         -0.162473
# 2          -0.398171  2.284918      2.664739    2.920190          4.319690
# 3          -0.110398 -0.437653     -0.422996   -0.396601         -0.415686
# 4          -0.398171 -0.437653     -0.422996   -0.520980         -0.511732
# ...              ...       ...           ...         ...               ...
# 14079      -0.398171  2.284918      2.664739    0.225298          0.012157
# 14080      -0.149967 -0.437653     -0.422996    1.013035          0.672839
# 14081      -0.295652  2.284918      2.664739   -0.520980         -0.511732
# 14082       0.465149 -0.437653     -0.422996    0.308217          0.652466
# 14083      -0.398171  2.284918      2.664739    1.634933          1.758454
#
#        Support Requests  Last visited minus Purchase date  Targets       ID
# 0              -0.14873                         -0.430080      0.0  29399.0
# 1              -0.14873                         -0.566128      0.0  25751.0
# 2              -0.14873                          1.814703      0.0   7814.0
# 3              -0.14873                          1.043767      0.0   8686.0
# 4              -0.14873                         -0.702175      0.0  20858.0
# ...                 ...                               ...      ...      ...
# 14079          -0.14873                         -0.271358      0.0  22955.0
# 14080          -0.14873                         -0.702175      0.0  22612.0
# 14081          -0.14873                         -0.702175      0.0   4041.0
# 14082          -0.14873                          1.361211      0.0   7670.0
# 14083          -0.14873                          1.168477      0.0   3807.0
#
# [14084 rows x 12 columns]

# %% [markdown]
# #### Balance the data
# Correct the distribution in the dataset. Aim for equal distributions. A quick inspection of the data (counting the targets for each class) shows that more customers did not convert and "skews" the distrbution. This can lead to a bias for the model (since it optimises for loss) to always predict non-conversion instead of properly trying to make a prediction.
#
# An easy solution is to take all the converted customers and selecting the same number of customers that were non-converted.

# %%
# Count the conversion frequencies
conversion_frequencies = shuffled_data.groupby(by='Targets').count().loc[:,'ID']
conversion_frequencies
# Out:
# Targets
# 0.0    11847
# 1.0     2237
# Name: ID, dtype: int64

# %%
#select the same amount of non-converted as converted instances
remove_indices = []
counter = 0
# for every index in the target dataframe
for i in range(len(shuffled_data)):
    # if the index is non-converted
    if shuffled_data['Targets'].iloc[i] == 0:
        # increase the counter
        counter += 1
        # if the non-converted limit is reached start listing the indices to be excluded
        if counter > conversion_frequencies.iloc[1]:
            remove_indices.append(i)
#remove the indices
balanced_data = shuffled_data.drop(remove_indices)
balanced_data
# Out:
#        Book length (mins)_avg  Book length (mins)_overall  Price_avg  \
# 0                   -0.799650                   -0.749232  -0.359686
# 1                    1.127687                    0.735156   0.181732
# 2                    1.127687                    0.735156  -0.359686
# 3                   -0.799650                   -0.749232  -0.035241
# 4                   -0.799650                   -0.749232  -0.359686
# ...                       ...                         ...        ...
# 14061                0.164019                    2.549408  -0.087963
# 14066                1.127687                    0.735156   0.552816
# 14068               -0.371353                    1.724748   0.613649
# 14076               -0.157204                    6.672708   0.072231
# 14078               -0.799650                   -0.749232   0.613649
#
#        Price_overall    Review  Review 10/10  Completion  Minutes_listened  \
# 0          -0.398171 -0.437653     -0.422996   -0.230761         -0.287624
# 1           0.082050 -0.437653     -0.422996   -0.272221         -0.162473
# 2          -0.398171  2.284918      2.664739    2.920190          4.319690
# 3          -0.110398 -0.437653     -0.422996   -0.396601         -0.415686
# 4          -0.398171 -0.437653     -0.422996   -0.520980         -0.511732
# ...              ...       ...           ...         ...               ...
# 14061       1.040695 -0.437653     -0.422996   -0.520980         -0.511732
# 14066       0.411191 -0.437653     -0.422996   -0.520980         -0.511732
# 14068       2.288912  2.284918      2.664739   -0.520980         -0.511732
# 14076       4.013753 -0.437653     -0.422996   -0.520980         -0.511732
# 14078       0.465149  2.284918      2.664739   -0.520980         -0.511732
#
#        Support Requests  Last visited minus Purchase date  Targets       ID
# 0             -0.148730                         -0.430080      0.0  29399.0
# 1             -0.148730                         -0.566128      0.0  25751.0
# 2             -0.148730                          1.814703      0.0   7814.0
# 3             -0.148730                          1.043767      0.0   8686.0
# 4             -0.148730                         -0.702175      0.0  20858.0
# ...                 ...                               ...      ...      ...
# 14061         -0.148730                         -0.702175      1.0   7223.0
# 14066         -0.148730                          0.386204      1.0  15292.0
# 14068         -0.148730                         -0.702175      1.0  20688.0
# 14076         -0.148730                          1.338537      1.0  25149.0
# 14078          1.969286                          1.270513      1.0  22270.0
#
# [4474 rows x 12 columns]

# %% [markdown]
# #### Shuffle the data again

# %%
# Save the column names
cols = balanced_data.columns.to_list()

# create evenly spaced values in the inputs dataframe
shuffled_indices = np.arange(balanced_data.values.shape[0])
# shuffle randomly
np.random.shuffle(shuffled_indices)

# set the new indices positions from the shuffle data on the non-shuffled data. Save as a Dataframe for intuitive veiwing using the cols saved
re_shuffled_data = pd.DataFrame(balanced_data.values[shuffled_indices],columns=cols)
re_shuffled_data
# Out:
#       Book length (mins)_avg  Book length (mins)_overall  Price_avg  \
# 0                   0.056944                   -0.089504   0.181732
# 1                  -0.799650                   -0.749232  -0.359686
# 2                  -1.870393                   -1.573892   0.181732
# 3                  -2.512839                   -2.068688   0.181732
# 4                  -0.799650                   -0.749232   0.613649
# ...                      ...                         ...        ...
# 4469               -0.799650                   -0.749232   0.181732
# 4470                1.127687                    0.735156  -0.244102
# 4471                1.127687                    0.735156   0.613649
# 4472                0.056944                   -0.089504   0.181732
# 4473                0.056944                   -0.089504  -0.359686
#
#       Price_overall    Review  Review 10/10  Completion  Minutes_listened  \
# 0          0.082050 -0.437653     -0.422996   -0.520980         -0.511732
# 1         -0.398171 -0.437653     -0.422996    0.474057          0.256638
# 2          0.082050  2.284918      2.664739   -0.520980         -0.511732
# 3          0.082050 -0.437653     -0.422996   -0.520980         -0.511732
# 4          0.465149 -0.437653     -0.422996   -0.520980         -0.511732
# ...             ...       ...           ...         ...               ...
# 4469       0.082050 -0.437653     -0.422996   -0.520980         -0.511732
# 4470      -0.295652 -0.437653     -0.422996   -0.520980         -0.511732
# 4471       0.465149 -0.437653     -0.422996   -0.396601         -0.337103
# 4472       0.082050 -0.437653     -0.422996    0.183838          0.230444
# 4473      -0.398171 -0.437653     -0.422996   -0.520980         -0.511732
#
#       Support Requests  Last visited minus Purchase date  Targets       ID
# 0             -0.14873                         -0.588803      0.0  20051.0
# 1             -0.14873                          2.653662      0.0  26739.0
# 2             -0.14873                          2.120810      1.0    708.0
# 3             -0.14873                         -0.520779      0.0  24408.0
# 4             -0.14873                         -0.702175      0.0  22581.0
# ...                ...                               ...      ...      ...
# 4469          -0.14873                          1.293188      1.0  24955.0
# 4470          -0.14873                         -0.702175      0.0  10211.0
# 4471          -0.14873                         -0.543453      0.0   1306.0
# 4472          -0.14873                          1.576620      0.0   2132.0
# 4473          -0.14873                          0.034748      1.0    843.0
#
# [4474 rows x 12 columns]

# %%
# check for balance
print("Sum Count Average")
print(np.sum(re_shuffled_data['Targets']), len(re_shuffled_data['Targets']), np.sum(re_shuffled_data['Targets'])/ len(re_shuffled_data['Targets']))
# Out:
# Sum Count Average
# 2237.0 4474 0.5

# %%
# count the balanced dataset
samples_count = re_shuffled_data.shape[0]

# determine the split by ratios
train_set_count = int(0.8*samples_count)
validation_set_count = int(0.1*samples_count)
test_set_count = validation_set_count

# %% [markdown]
# ### Divide the dataset into training, validation and test sets
# We are opting for an 80, 10 , 10 split. Even though we have balanced the whole dataset, each set may be unbalanced and we should check for this. If the sets are unbalanced we should shuffle before taking each set.

# %%
# extract the train set
train_set = re_shuffled_data.iloc[:train_set_count]
# check for balance
print("Sum Count Average")
print(np.sum(train_set['Targets']), train_set_count, np.sum(train_set['Targets'])/train_set_count)
# Out:
# Sum Count Average
# 1791.0 3579 0.5004191114836547

# %%
# extract the validation set
validation_set = re_shuffled_data.iloc[train_set_count:train_set_count+validation_set_count]
# check for balance
print("Sum Count Average")
print(np.sum(validation_set['Targets']), validation_set_count, np.sum(validation_set['Targets'])/validation_set_count)
# Out:
# Sum Count Average
# 228.0 447 0.5100671140939598

# %%
# extract the test set
test_set = re_shuffled_data.iloc[train_set_count+validation_set_count:]
# check for balance
print("Sum Count Average")
print(np.sum(test_set['Targets']), test_set_count, np.sum(test_set['Targets'])/test_set_count)
# Out:
# Sum Count Average
# 218.0 447 0.48769574944071586

# %% [markdown]
# ### Outline the model(s)
# #### Model Type
# Classifiction with two outcome classes. Converted or non-converted.
#
# #### Model design
# ##### Hyperparameters
# Hidden Layers = 2,4,8
# Hidden Layer width = 12,24,48
# Hidden Layer Activation Functions = Relu,
# Output Layer Activation Function = Softmax,
# Batch Size = 100,
# Number of Epochs = 100
# Early Stopping on val_loss to prevent over fitting, patience = 2, restore best values = True
#
# ##### Paramters
# Input Layer = 10,
# Output Layer = 2
# Optimizer = 'Adam'
# Learning Rate = 0.001
# Loss = 'sparse_categorical_cross_entropy'

# %%
#Parameters
input_layer_width = 11
output_layer_width = 2
custom_optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
#Hyperparameters
hidden_layer_widths = [4,12]
hidden_layer_depths = [2,4]
BATCH_SIZE = 200
max_epochs = 1000
early_stopping = tf.keras.callbacks.EarlyStopping(
                            monitor='val_loss',
                            min_delta=0,
                            patience=2,
                            verbose=0,
                            mode='min',
                            restore_best_weights=False)

# %%
# construct the models
model_dict = construct(optimizer=custom_optimizer,output_length = output_layer_width, mode='sequential', flatten_input=False,list_of_widths=hidden_layer_widths, list_of_depths=hidden_layer_depths)
# Out:
# Constructing a 4x2 model
# Constructing a 4x4 model
# Constructing a 12x2 model
# Constructing a 12x4 model

# %% [markdown]
# ### Train the models

# %%
# for each model in the dictionary
for label in model_dict:
    # fit the model
    print(f"#####################\n{label} model\n#####################")
    model_dict[label].fit(
        train_set.iloc[:,:-2].values,
        train_set.iloc[:,-2:-1].values,
        epochs=max_epochs,
        callbacks=[early_stopping],
        validation_data=(validation_set.iloc[:,:-2].values,validation_set.iloc[:,-2:-1].values),
        batch_size=BATCH_SIZE,
        verbose=2)
    print("\n")
# Out:
# #####################
# 4x2 model
# #####################
# Epoch 1/1000
# 18/18 - 0s - loss: 0.6937 - accuracy: 0.5130 - val_loss: 0.6937 - val_accuracy: 0.5526
# Epoch 2/1000
# 18/18 - 0s - loss: 0.6895 - accuracy: 0.5569 - val_loss: 0.6899 - val_accuracy: 0.5727
# Epoch 3/1000
# 18/18 - 0s - loss: 0.6860 - accuracy: 0.5781 - val_loss: 0.6865 - val_accuracy: 0.5772
# Epoch 4/1000
# 18/18 - 0s - loss: 0.6825 - accuracy: 0.5915 - val_loss: 0.6827 - val_accuracy: 0.5884
# Epoch 5/1000
# 18/18 - 0s - loss: 0.6784 - accuracy: 0.5951 - val_loss: 0.6784 - val_accuracy: 0.5951
# Epoch 6/1000
# 18/18 - 0s - loss: 0.6734 - accuracy: 0.6125 - val_loss: 0.6734 - val_accuracy: 0.5996
# Epoch 7/1000
# 18/18 - 0s - loss: 0.6672 - accuracy: 0.6343 - val_loss: 0.6676 - val_accuracy: 0.6130
# Epoch 8/1000
# 18/18 - 0s - loss: 0.6600 - accuracy: 0.6471 - val_loss: 0.6604 - val_accuracy: 0.6219
# Epoch 9/1000
# 18/18 - 0s - loss: 0.6512 - accuracy: 0.6544 - val_loss: 0.6523 - val_accuracy: 0.6488
# Epoch 10/1000
# 18/18 - 0s - loss: 0.6417 - accuracy: 0.6658 - val_loss: 0.6428 - val_accuracy: 0.6711
# Epoch 11/1000
# 18/18 - 0s - loss: 0.6309 - accuracy: 0.6767 - val_loss: 0.6320 - val_accuracy: 0.6823
# Epoch 12/1000
# 18/18 - 0s - loss: 0.6194 - accuracy: 0.6871 - val_loss: 0.6207 - val_accuracy: 0.6868
# Epoch 13/1000
# 18/18 - 0s - loss: 0.6075 - accuracy: 0.6960 - val_loss: 0.6090 - val_accuracy: 0.6935
# Epoch 14/1000
# 18/18 - 0s - loss: 0.5951 - accuracy: 0.7044 - val_loss: 0.5976 - val_accuracy: 0.7002
# Epoch 15/1000
# 18/18 - 0s - loss: 0.5831 - accuracy: 0.7105 - val_loss: 0.5861 - val_accuracy: 0.7069
# Epoch 16/1000
# 18/18 - 0s - loss: 0.5706 - accuracy: 0.7198 - val_loss: 0.5742 - val_accuracy: 0.7114
# Epoch 17/1000
# 18/18 - 0s - loss: 0.5570 - accuracy: 0.7273 - val_loss: 0.5617 - val_accuracy: 0.7204
# Epoch 18/1000
# 18/18 - 0s - loss: 0.5443 - accuracy: 0.7334 - val_loss: 0.5503 - val_accuracy: 0.7226
# Epoch 19/1000
# 18/18 - 0s - loss: 0.5320 - accuracy: 0.7371 - val_loss: 0.5396 - val_accuracy: 0.7248
# Epoch 20/1000
# 18/18 - 0s - loss: 0.5199 - accuracy: 0.7466 - val_loss: 0.5290 - val_accuracy: 0.7338
# Epoch 21/1000
# 18/18 - 0s - loss: 0.5086 - accuracy: 0.7533 - val_loss: 0.5183 - val_accuracy: 0.7338
# Epoch 22/1000
# 18/18 - 0s - loss: 0.4977 - accuracy: 0.7583 - val_loss: 0.5072 - val_accuracy: 0.7450
# Epoch 23/1000
# 18/18 - 0s - loss: 0.4862 - accuracy: 0.7633 - val_loss: 0.4962 - val_accuracy: 0.7494
# Epoch 24/1000
# 18/18 - 0s - loss: 0.4747 - accuracy: 0.7664 - val_loss: 0.4852 - val_accuracy: 0.7539
# Epoch 25/1000
# 18/18 - 0s - loss: 0.4652 - accuracy: 0.7670 - val_loss: 0.4757 - val_accuracy: 0.7562
# Epoch 26/1000
# 18/18 - 0s - loss: 0.4567 - accuracy: 0.7714 - val_loss: 0.4670 - val_accuracy: 0.7562
# Epoch 27/1000
# 18/18 - 0s - loss: 0.4493 - accuracy: 0.7706 - val_loss: 0.4592 - val_accuracy: 0.7606
# Epoch 28/1000
# 18/18 - 0s - loss: 0.4429 - accuracy: 0.7728 - val_loss: 0.4526 - val_accuracy: 0.7606
# Epoch 29/1000
# 18/18 - 0s - loss: 0.4371 - accuracy: 0.7740 - val_loss: 0.4464 - val_accuracy: 0.7651
# Epoch 30/1000
# 18/18 - 0s - loss: 0.4322 - accuracy: 0.7762 - val_loss: 0.4410 - val_accuracy: 0.7629
# Epoch 31/1000
# 18/18 - 0s - loss: 0.4280 - accuracy: 0.7759 - val_loss: 0.4361 - val_accuracy: 0.7651
# Epoch 32/1000
# 18/18 - 0s - loss: 0.4238 - accuracy: 0.7768 - val_loss: 0.4324 - val_accuracy: 0.7673
# Epoch 33/1000
# 18/18 - 0s - loss: 0.4202 - accuracy: 0.7793 - val_loss: 0.4269 - val_accuracy: 0.7718
# Epoch 34/1000
# 18/18 - 0s - loss: 0.4164 - accuracy: 0.7784 - val_loss: 0.4221 - val_accuracy: 0.7718
# Epoch 35/1000
# 18/18 - 0s - loss: 0.4132 - accuracy: 0.7823 - val_loss: 0.4182 - val_accuracy: 0.7808
# Epoch 36/1000
# 18/18 - 0s - loss: 0.4097 - accuracy: 0.7849 - val_loss: 0.4140 - val_accuracy: 0.7897
# Epoch 37/1000
# 18/18 - 0s - loss: 0.4064 - accuracy: 0.7882 - val_loss: 0.4104 - val_accuracy: 0.7785
# Epoch 38/1000
# 18/18 - 0s - loss: 0.4035 - accuracy: 0.7857 - val_loss: 0.4062 - val_accuracy: 0.7942
# Epoch 39/1000
# 18/18 - 0s - loss: 0.4009 - accuracy: 0.7888 - val_loss: 0.4032 - val_accuracy: 0.7897
# Epoch 40/1000
# 18/18 - 0s - loss: 0.3981 - accuracy: 0.7927 - val_loss: 0.4002 - val_accuracy: 0.7897
# Epoch 41/1000
# 18/18 - 0s - loss: 0.3961 - accuracy: 0.7921 - val_loss: 0.3967 - val_accuracy: 0.7897
# Epoch 42/1000
# 18/18 - 0s - loss: 0.3942 - accuracy: 0.7916 - val_loss: 0.3943 - val_accuracy: 0.7942
# Epoch 43/1000
# 18/18 - 0s - loss: 0.3922 - accuracy: 0.7960 - val_loss: 0.3910 - val_accuracy: 0.7919
# Epoch 44/1000
# 18/18 - 0s - loss: 0.3906 - accuracy: 0.7952 - val_loss: 0.3897 - val_accuracy: 0.7919
# Epoch 45/1000
# 18/18 - 0s - loss: 0.3887 - accuracy: 0.7963 - val_loss: 0.3881 - val_accuracy: 0.7987
# Epoch 46/1000
# 18/18 - 0s - loss: 0.3874 - accuracy: 0.7983 - val_loss: 0.3864 - val_accuracy: 0.7875
# Epoch 47/1000
# 18/18 - 0s - loss: 0.3863 - accuracy: 0.7969 - val_loss: 0.3854 - val_accuracy: 0.8098
# Epoch 48/1000
# 18/18 - 0s - loss: 0.3858 - accuracy: 0.7980 - val_loss: 0.3834 - val_accuracy: 0.8009
# Epoch 49/1000
# 18/18 - 0s - loss: 0.3841 - accuracy: 0.7997 - val_loss: 0.3828 - val_accuracy: 0.7987
# Epoch 50/1000
# 18/18 - 0s - loss: 0.3833 - accuracy: 0.7966 - val_loss: 0.3812 - val_accuracy: 0.7875
# Epoch 51/1000
# 18/18 - 0s - loss: 0.3817 - accuracy: 0.7991 - val_loss: 0.3804 - val_accuracy: 0.8009
# Epoch 52/1000
# 18/18 - 0s - loss: 0.3806 - accuracy: 0.7983 - val_loss: 0.3790 - val_accuracy: 0.7942
# Epoch 53/1000
# 18/18 - 0s - loss: 0.3798 - accuracy: 0.8013 - val_loss: 0.3780 - val_accuracy: 0.7942
# Epoch 54/1000
# 18/18 - 0s - loss: 0.3788 - accuracy: 0.7985 - val_loss: 0.3769 - val_accuracy: 0.7942
# Epoch 55/1000
# 18/18 - 0s - loss: 0.3782 - accuracy: 0.7980 - val_loss: 0.3758 - val_accuracy: 0.7942
# Epoch 56/1000
# 18/18 - 0s - loss: 0.3774 - accuracy: 0.7999 - val_loss: 0.3754 - val_accuracy: 0.7942
# Epoch 57/1000
# 18/18 - 0s - loss: 0.3766 - accuracy: 0.8002 - val_loss: 0.3743 - val_accuracy: 0.7987
# Epoch 58/1000
# 18/18 - 0s - loss: 0.3766 - accuracy: 0.7977 - val_loss: 0.3740 - val_accuracy: 0.8076
# Epoch 59/1000
# 18/18 - 0s - loss: 0.3760 - accuracy: 0.8008 - val_loss: 0.3729 - val_accuracy: 0.7942
# Epoch 60/1000
# 18/18 - 0s - loss: 0.3744 - accuracy: 0.8008 - val_loss: 0.3726 - val_accuracy: 0.8076
# Epoch 61/1000
# 18/18 - 0s - loss: 0.3739 - accuracy: 0.8019 - val_loss: 0.3714 - val_accuracy: 0.8031
# Epoch 62/1000
# 18/18 - 0s - loss: 0.3732 - accuracy: 0.8013 - val_loss: 0.3711 - val_accuracy: 0.8054
# Epoch 63/1000
# 18/18 - 0s - loss: 0.3728 - accuracy: 0.8025 - val_loss: 0.3705 - val_accuracy: 0.8098
# Epoch 64/1000
# 18/18 - 0s - loss: 0.3723 - accuracy: 0.8030 - val_loss: 0.3700 - val_accuracy: 0.7919
# Epoch 65/1000
# 18/18 - 0s - loss: 0.3718 - accuracy: 0.8005 - val_loss: 0.3707 - val_accuracy: 0.8143
# Epoch 66/1000
# 18/18 - 0s - loss: 0.3711 - accuracy: 0.8016 - val_loss: 0.3690 - val_accuracy: 0.8076
# Epoch 67/1000
# 18/18 - 0s - loss: 0.3704 - accuracy: 0.8027 - val_loss: 0.3682 - val_accuracy: 0.8076
# Epoch 68/1000
# 18/18 - 0s - loss: 0.3702 - accuracy: 0.8033 - val_loss: 0.3682 - val_accuracy: 0.8054
# Epoch 69/1000
# 18/18 - 0s - loss: 0.3700 - accuracy: 0.8013 - val_loss: 0.3679 - val_accuracy: 0.8121
# Epoch 70/1000
# 18/18 - 0s - loss: 0.3692 - accuracy: 0.8025 - val_loss: 0.3674 - val_accuracy: 0.8031
# Epoch 71/1000
# 18/18 - 0s - loss: 0.3689 - accuracy: 0.8022 - val_loss: 0.3664 - val_accuracy: 0.8143
# Epoch 72/1000
# 18/18 - 0s - loss: 0.3685 - accuracy: 0.8030 - val_loss: 0.3669 - val_accuracy: 0.8031
# Epoch 73/1000
# 18/18 - 0s - loss: 0.3683 - accuracy: 0.8005 - val_loss: 0.3667 - val_accuracy: 0.8166
#
#
# #####################
# 4x4 model
# #####################
# Epoch 1/1000
# 18/18 - 0s - loss: 0.6943 - accuracy: 0.5094 - val_loss: 0.6920 - val_accuracy: 0.5347
# Epoch 2/1000
# 18/18 - 0s - loss: 0.6907 - accuracy: 0.5356 - val_loss: 0.6899 - val_accuracy: 0.5213
# Epoch 3/1000
# 18/18 - 0s - loss: 0.6851 - accuracy: 0.5672 - val_loss: 0.6844 - val_accuracy: 0.5570
# Epoch 4/1000
# 18/18 - 0s - loss: 0.6774 - accuracy: 0.5949 - val_loss: 0.6758 - val_accuracy: 0.6107
# Epoch 5/1000
# 18/18 - 0s - loss: 0.6678 - accuracy: 0.6340 - val_loss: 0.6634 - val_accuracy: 0.6398
# Epoch 6/1000
# 18/18 - 0s - loss: 0.6544 - accuracy: 0.6683 - val_loss: 0.6462 - val_accuracy: 0.6734
# Epoch 7/1000
# 18/18 - 0s - loss: 0.6354 - accuracy: 0.7019 - val_loss: 0.6280 - val_accuracy: 0.6980
# Epoch 8/1000
# 18/18 - 0s - loss: 0.6099 - accuracy: 0.7404 - val_loss: 0.5949 - val_accuracy: 0.7450
# Epoch 9/1000
# 18/18 - 0s - loss: 0.5815 - accuracy: 0.7547 - val_loss: 0.5658 - val_accuracy: 0.7562
# Epoch 10/1000
# 18/18 - 0s - loss: 0.5504 - accuracy: 0.7698 - val_loss: 0.5383 - val_accuracy: 0.7808
# Epoch 11/1000
# 18/18 - 0s - loss: 0.5219 - accuracy: 0.7776 - val_loss: 0.5140 - val_accuracy: 0.7785
# Epoch 12/1000
# 18/18 - 0s - loss: 0.4971 - accuracy: 0.7854 - val_loss: 0.4993 - val_accuracy: 0.7673
# Epoch 13/1000
# 18/18 - 0s - loss: 0.4779 - accuracy: 0.7932 - val_loss: 0.4777 - val_accuracy: 0.8009
# Epoch 14/1000
# 18/18 - 0s - loss: 0.4639 - accuracy: 0.7952 - val_loss: 0.4665 - val_accuracy: 0.7942
# Epoch 15/1000
# 18/18 - 0s - loss: 0.4567 - accuracy: 0.7927 - val_loss: 0.4577 - val_accuracy: 0.8009
# Epoch 16/1000
# 18/18 - 0s - loss: 0.4503 - accuracy: 0.7888 - val_loss: 0.4546 - val_accuracy: 0.7785
# Epoch 17/1000
# 18/18 - 0s - loss: 0.4402 - accuracy: 0.7918 - val_loss: 0.4487 - val_accuracy: 0.7830
# Epoch 18/1000
# 18/18 - 0s - loss: 0.4377 - accuracy: 0.7907 - val_loss: 0.4389 - val_accuracy: 0.8009
# Epoch 19/1000
# 18/18 - 0s - loss: 0.4303 - accuracy: 0.8022 - val_loss: 0.4323 - val_accuracy: 0.7987
# Epoch 20/1000
# 18/18 - 0s - loss: 0.4241 - accuracy: 0.7974 - val_loss: 0.4266 - val_accuracy: 0.7875
# Epoch 21/1000
# 18/18 - 0s - loss: 0.4158 - accuracy: 0.8013 - val_loss: 0.4170 - val_accuracy: 0.7897
# Epoch 22/1000
# 18/18 - 0s - loss: 0.4075 - accuracy: 0.8002 - val_loss: 0.4070 - val_accuracy: 0.8076
# Epoch 23/1000
# 18/18 - 0s - loss: 0.4000 - accuracy: 0.8025 - val_loss: 0.4025 - val_accuracy: 0.7942
# Epoch 24/1000
# 18/18 - 0s - loss: 0.3953 - accuracy: 0.8027 - val_loss: 0.3950 - val_accuracy: 0.8054
# Epoch 25/1000
# 18/18 - 0s - loss: 0.3925 - accuracy: 0.8019 - val_loss: 0.3899 - val_accuracy: 0.8054
# Epoch 26/1000
# 18/18 - 0s - loss: 0.3898 - accuracy: 0.8011 - val_loss: 0.3869 - val_accuracy: 0.8076
# Epoch 27/1000
# 18/18 - 0s - loss: 0.3872 - accuracy: 0.8002 - val_loss: 0.3864 - val_accuracy: 0.8255
# Epoch 28/1000
# 18/18 - 0s - loss: 0.3859 - accuracy: 0.7997 - val_loss: 0.3829 - val_accuracy: 0.8076
# Epoch 29/1000
# 18/18 - 0s - loss: 0.3847 - accuracy: 0.7991 - val_loss: 0.3809 - val_accuracy: 0.8098
# Epoch 30/1000
# 18/18 - 0s - loss: 0.3832 - accuracy: 0.8044 - val_loss: 0.3798 - val_accuracy: 0.8098
# Epoch 31/1000
# 18/18 - 0s - loss: 0.3817 - accuracy: 0.7991 - val_loss: 0.3809 - val_accuracy: 0.8031
# Epoch 32/1000
# 18/18 - 0s - loss: 0.3805 - accuracy: 0.8033 - val_loss: 0.3801 - val_accuracy: 0.8009
#
#
# #####################
# 12x2 model
# #####################
# Epoch 1/1000
# 18/18 - 0s - loss: 0.5721 - accuracy: 0.6857 - val_loss: 0.5081 - val_accuracy: 0.7293
# Epoch 2/1000
# 18/18 - 0s - loss: 0.4622 - accuracy: 0.7659 - val_loss: 0.4348 - val_accuracy: 0.7808
# Epoch 3/1000
# 18/18 - 0s - loss: 0.4180 - accuracy: 0.7835 - val_loss: 0.4038 - val_accuracy: 0.7964
# Epoch 4/1000
# 18/18 - 0s - loss: 0.3983 - accuracy: 0.7890 - val_loss: 0.3922 - val_accuracy: 0.8009
# Epoch 5/1000
# 18/18 - 0s - loss: 0.3886 - accuracy: 0.7946 - val_loss: 0.3834 - val_accuracy: 0.8076
# Epoch 6/1000
# 18/18 - 0s - loss: 0.3822 - accuracy: 0.7988 - val_loss: 0.3723 - val_accuracy: 0.8210
# Epoch 7/1000
# 18/18 - 0s - loss: 0.3788 - accuracy: 0.7977 - val_loss: 0.3723 - val_accuracy: 0.8166
# Epoch 8/1000
# 18/18 - 0s - loss: 0.3751 - accuracy: 0.7997 - val_loss: 0.3638 - val_accuracy: 0.8210
# Epoch 9/1000
# 18/18 - 0s - loss: 0.3723 - accuracy: 0.8019 - val_loss: 0.3636 - val_accuracy: 0.8188
# Epoch 10/1000
# 18/18 - 0s - loss: 0.3691 - accuracy: 0.8047 - val_loss: 0.3609 - val_accuracy: 0.8233
# Epoch 11/1000
# 18/18 - 0s - loss: 0.3666 - accuracy: 0.8061 - val_loss: 0.3597 - val_accuracy: 0.8166
# Epoch 12/1000
# 18/18 - 0s - loss: 0.3652 - accuracy: 0.8075 - val_loss: 0.3585 - val_accuracy: 0.8210
# Epoch 13/1000
# 18/18 - 0s - loss: 0.3635 - accuracy: 0.8078 - val_loss: 0.3528 - val_accuracy: 0.8277
# Epoch 14/1000
# 18/18 - 0s - loss: 0.3622 - accuracy: 0.8078 - val_loss: 0.3575 - val_accuracy: 0.8277
# Epoch 15/1000
# 18/18 - 0s - loss: 0.3606 - accuracy: 0.8092 - val_loss: 0.3562 - val_accuracy: 0.8277
#
#
# #####################
# 12x4 model
# #####################
# Epoch 1/1000
# 18/18 - 0s - loss: 0.6648 - accuracy: 0.5708 - val_loss: 0.6119 - val_accuracy: 0.6890
# Epoch 2/1000
# 18/18 - 0s - loss: 0.5649 - accuracy: 0.7270 - val_loss: 0.4975 - val_accuracy: 0.7584
# Epoch 3/1000
# 18/18 - 0s - loss: 0.4569 - accuracy: 0.7728 - val_loss: 0.4141 - val_accuracy: 0.7852
# Epoch 4/1000
# 18/18 - 0s - loss: 0.4134 - accuracy: 0.7818 - val_loss: 0.3968 - val_accuracy: 0.7852
# Epoch 5/1000
# 18/18 - 0s - loss: 0.3964 - accuracy: 0.7874 - val_loss: 0.3792 - val_accuracy: 0.8054
# Epoch 6/1000
# 18/18 - 0s - loss: 0.3840 - accuracy: 0.7921 - val_loss: 0.3700 - val_accuracy: 0.8143
# Epoch 7/1000
# 18/18 - 0s - loss: 0.3793 - accuracy: 0.7974 - val_loss: 0.3658 - val_accuracy: 0.8031
# Epoch 8/1000
# 18/18 - 0s - loss: 0.3738 - accuracy: 0.8005 - val_loss: 0.3665 - val_accuracy: 0.8210
# Epoch 9/1000
# 18/18 - 0s - loss: 0.3721 - accuracy: 0.7999 - val_loss: 0.3609 - val_accuracy: 0.8277
# Epoch 10/1000
# 18/18 - 0s - loss: 0.3707 - accuracy: 0.8033 - val_loss: 0.3608 - val_accuracy: 0.7875
# Epoch 11/1000
# 18/18 - 0s - loss: 0.3712 - accuracy: 0.8022 - val_loss: 0.3625 - val_accuracy: 0.8031
# Epoch 12/1000
# 18/18 - 0s - loss: 0.3640 - accuracy: 0.8036 - val_loss: 0.3723 - val_accuracy: 0.7987

# %% [markdown]
# ### Testing the models

# %%
# for each model in the dictionary
for label in model_dict:
    print(f'{label} model')
    test_loss, test_accuracy = model_dict[label].evaluate(test_set.iloc[:,:-2].values,test_set.iloc[:,-2:-1].values)
    import os
    working_directory = os.getcwd()
    print(working_directory)
    model_dict[label].save_weights(working_directory+f'\\{label}_model_trained')
# Out:
# 4x2 model
# 14/14 [==============================] - 0s 776us/step - loss: 0.3613 - accuracy: 0.8304
# C:\Users\pjjvn\Google Drive\Programming\audiobook_business_case
# 4x4 model
# 14/14 [==============================] - 0s 930us/step - loss: 0.3604 - accuracy: 0.8036
# C:\Users\pjjvn\Google Drive\Programming\audiobook_business_case
# 12x2 model
# 14/14 [==============================] - 0s 961us/step - loss: 0.3510 - accuracy: 0.8147
# C:\Users\pjjvn\Google Drive\Programming\audiobook_business_case
# 12x4 model
# 14/14 [==============================] - 0s 855us/step - loss: 0.3448 - accuracy: 0.8348
# C:\Users\pjjvn\Google Drive\Programming\audiobook_business_case

# %% [markdown]
# # Insight
# The model was trained on a shuffled dataset, that was then balanced by excluding "extra" non-converted targets and retaining all converted targets. This was performed to obtain an equal distribution of converted and non-converted targets. The data was shuffled again and then split into test, validation and test sets in order to obtain an equal distribution in each set.
#
# With the current outlines, the models are able to predict approximatly 80-83% of the customer's behaviour correctly. That is 8 out of 10 customers.
